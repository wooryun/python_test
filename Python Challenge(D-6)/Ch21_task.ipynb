# %% [markdown]
# 안녕하세요. 수강생 여러분~! Chapter21 ~ 32 수업은 잘 들으셨나요?
#
# Chapter21 ~ 32의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# ---

# %% [markdown]
# [문제 1]
# 사용자로부터 이름과 나이를 입력 받아, "안녕하세요, [이름]님! 당신은 [나이]살입니다."라고 출력하는 함수 greet_user를 작성하세요.

# %%
def greet_user():
    name = input('이름을 입력하세요. :')
    age = input('나이를 입력하세요. :')
    print(f'안녕하세요, {name}님! 당신은 {age}살입니다.')

greet_user()
# Out:
# 안녕하세요, 김코딩님! 당신은 30살입니다.

# %% [markdown]
# ---

# %% [markdown]
# [문제 2] 여러 숫자를 입력받아 그 합계를 반환하는 함수 sum_numbers를 작성하세요. 이 때, 가변 매개변수를 사용하세요.

# %%
def sum_numbers(*nums):
    print('합계 :', sum(nums))

nums_input = list(map(int, input('숫자를 입력해주세요. :').split(',')))

sum_numbers(*nums_input)
# Out:
# 합계 : 100

# %% [markdown]
# ---

# %% [markdown]
# [문제 3] 사용자의 이름을 출력하는 함수 print_name을 작성하세요. 만약 이름이 주어지지 않았다면, 기본값으로 "익명"을 사용하세요.

# %%
def print_name(name='익명'):
    print(name)

print_name()
print_name('김코딩')
# Out:
# 익명
# 김코딩

# %% [markdown]
# ---

# %% [markdown]
# [문제 4] 사용자의 이름, 나이, 성별을 출력하는 함수 print_info를 작성하세요. 이 때, 모든 매개변수는 키워드 매개변수로만 받도록 하세요.

# %%
def print_info(*, name, age, gender):
    print(f'이름 : {name}')
    print(f'나이 : {age}')
    print(f'성별 : {gender}')

print_info(name = '김코딩', age = 30, gender = '남자')
# Out:
# 이름 : 김코딩
# 나이 : 30
# 성별 : 남자

# %% [markdown]
# ---

# %% [markdown]
# [문제 5] 두 개의 정수를 받아 합을 반환하는 함수 add를 작성하세요. 매개변수와 반환값에 타입 어노테이션을 추가하세요.

# %%
def add(num1: int, num2: int) -> int:
    return num1 + num2

print(add(10,21))
# Out:
# 31

# %% [markdown]
# ---

# %% [markdown]
# [문제 6] 0부터 시작하여 n까지의 숫자 중에서 홀수만 생성하는 제너레이터 odd_numbers를 작성하세요.

# %%
def odd_numbers(n):
    for i in range(1, n + 1, 2):
        yield i

for num in odd_numbers(15):
    print(num)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11
# 13
# 15

# %% [markdown]
# ---

# %% [markdown]
# [문제 7] 두 숫자를 더하는 람다 함수를 작성하고, 이를 변수에 할당한 후 사용하세요.

# %%
add = lambda a, b : a + b

a, b = list(map(int, input('숫자를 입력해주세요. :').split(',')))

# a = int(input('첫 번째 숫자를 입력해주세요. :'))
# b = int(input('두 번째 숫자를 입력해주세요. :'))

print('합계 :', add(a, b))
# Out:
# 합계 : 21

# %% [markdown]
# ---

# %% [markdown]
# [문제 8] 사용자로부터 3개의 숫자를 입력받아, 이를 튜플로 만든 후 최소값과 최대값을 출력하는 함수 min_max를 작성하세요.

# %%
# def min_max(nums1, nums2, nums3):
#     nums_tuple = (nums1, nums2, nums3)
#     return nums_tuple, min(nums_tuple), max(nums_tuple)

# nums1 = int(input('첫 번째 숫자를 입력해주세요. :'))
# nums2 = int(input('두 번째 숫자를 입력해주세요. :'))
# nums3 = int(input('세 번째 숫자를 입력해주세요. :'))

# nums_normal, nums_min, nums_max = min_max(nums1, nums2, nums3)

# print('입력된 튜플 :', nums_normal)
# print('최소값 : ',nums_min)
# print('최대값 : ',nums_max)


def min_max():
    num1 = int(input("첫 번째 숫자: "))
    num2 = int(input("두 번째 숫자: "))
    num3 = int(input("세 번째 숫자: "))

    numbers_tuple = (num1, num2, num3)

    min_val = min(numbers_tuple)
    max_val = max(numbers_tuple)

    print(f"입력된 튜플: {numbers_tuple}")
    print(f"최소값: {min_val}")
    print(f"최대값: {max_val}")
min_max()
# Out:
# 입력된 튜플: (45, 13, 21)
# 최소값: 13
# 최대값: 45

# %% [markdown]
# ---

# %% [markdown]
# [문제 9] 주어진 숫자가 짝수인지 확인하는 함수 is_even을 작성하세요. 짝수라면 True를, 아니라면 False를 반환하세요. 함수 내에서 조기 리턴을 활용하세요.

# %%
def is_even(number):
    return number % 2 == 0

print(is_even(5))
print(is_even(10))
# Out:
# False
# True

# %% [markdown]
# ---

# %% [markdown]
# [문제 10] 팩토리얼을 계산하는 재귀 함수 factorial을 작성하세요.

# %%
def factorial(n):
    if n <= 1:
        return 1
    else:
        return n * factorial(n-1)

print(factorial(20))
# Out:
# 2432902008176640000

# %% [markdown]
# ---

# %% [markdown]
# [문제 11] 문자열 리스트를 받아, 각 문자열의 길이를 출력하는 함수 print_lengths를 작성하세요.

# %%
def print_lengths(str):
    for string in str:
        print(len(string))

print_lengths(['hello', 'python', 'english'])
# Out:
# 5
# 6
# 7

# %% [markdown]
# ---

# %% [markdown]
# [문제 12] 두 문자열을 받아서 긴 문자열을 반환하는 함수 longer_string을 작성하세요. 만약 두 문자열의 길이가 같다면, 첫 번째 문자열을 반환하세요.

# %%
def longer_string(str1, str2):
    if len(str1) >= len(str2):
        return str1
    else:
        return str2

print(longer_string('hello', 'world'))
# Out:
# hello
